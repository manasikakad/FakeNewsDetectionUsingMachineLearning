# %% [markdown]
# # Fake news detection using ML

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Read datasets

# %%
fake = pd.read_csv("data/Fake.csv")
true = pd.read_csv("data/True.csv")

# %%
fake.shape
# Out:
# (23481, 4)

# %%
true.shape
# Out:
# (21417, 4)

# %% [markdown]
# ## Data cleaning and preparation

# %%
# Add flag to track fake and real
fake['target'] = 'fake'
true['target'] = 'true'

# %%
# Concatenate dataframes
data = pd.concat([fake, true]).reset_index(drop = True)
data.shape
# Out:
# (44898, 5)

# %%
# Shuffle the data
from sklearn.utils import shuffle
data = shuffle(data)
data = data.reset_index(drop=True)

# %%
# Check the data
data.head()
# Out:
#                                                title  \
# 0  BRONX HOSPITAL SHOOTING: Multiple People Shot,...
# 1  HOW PAUL RYAN JUST Made A Mockery Of Trump’s P...
# 2  EU's Juncker says ready to retaliate if needed...
# 3   Sean Hannity Is Totally Butthurt Over This On...
# 4  FLASHBACK: ‘The Syrian War: What You’re Not Be...
#
#                                                 text       subject  \
# 0  21st Century Wire says Several people have bee...       US_News
# 1  The bipartisan congressional language creates ...      politics
# 2  BRUSSELS (Reuters) - The European Union’s chie...  politicsNews
# 3  Sean Hannity is giddy and offended that finall...          News
# 4  21st Century Wire says Back in August 2013, Un...   Middle-east
#
#                 date target
# 0      June 30, 2017   fake
# 1        May 2, 2017   fake
# 2    August 2, 2017    true
# 3       June 3, 2017   fake
# 4  December 18, 2016   fake

# %%
# Removing the date (we won't use it for the analysis)
data.drop(["date"],axis=1,inplace=True)
data.head()
# Out:
#                                                title  \
# 0  BRONX HOSPITAL SHOOTING: Multiple People Shot,...
# 1  HOW PAUL RYAN JUST Made A Mockery Of Trump’s P...
# 2  EU's Juncker says ready to retaliate if needed...
# 3   Sean Hannity Is Totally Butthurt Over This On...
# 4  FLASHBACK: ‘The Syrian War: What You’re Not Be...
#
#                                                 text       subject target
# 0  21st Century Wire says Several people have bee...       US_News   fake
# 1  The bipartisan congressional language creates ...      politics   fake
# 2  BRUSSELS (Reuters) - The European Union’s chie...  politicsNews   true
# 3  Sean Hannity is giddy and offended that finall...          News   fake
# 4  21st Century Wire says Back in August 2013, Un...   Middle-east   fake

# %%
# Removing the title (we will only use the text)
data.drop(["title"],axis=1,inplace=True)
data.head()
# Out:
#                                                 text       subject target
# 0  21st Century Wire says Several people have bee...       US_News   fake
# 1  The bipartisan congressional language creates ...      politics   fake
# 2  BRUSSELS (Reuters) - The European Union’s chie...  politicsNews   true
# 3  Sean Hannity is giddy and offended that finall...          News   fake
# 4  21st Century Wire says Back in August 2013, Un...   Middle-east   fake

# %%
# Convert to lowercase

data['text'] = data['text'].apply(lambda x: x.lower())
data.head()
# Out:
#                                                 text       subject target
# 0  21st century wire says several people have bee...       US_News   fake
# 1  the bipartisan congressional language creates ...      politics   fake
# 2  brussels (reuters) - the european union’s chie...  politicsNews   true
# 3  sean hannity is giddy and offended that finall...          News   fake
# 4  21st century wire says back in august 2013, un...   Middle-east   fake

# %%
# Remove punctuation

import string

def punctuation_removal(text):
    all_list = [char for char in text if char not in string.punctuation]
    clean_str = ''.join(all_list)
    return clean_str

data['text'] = data['text'].apply(punctuation_removal)

# %%
# Check
data.head()
# Out:
#                                                 text       subject target
# 0  21st century wire says several people have bee...       US_News   fake
# 1  the bipartisan congressional language creates ...      politics   fake
# 2  brussels reuters  the european union’s chief e...  politicsNews   true
# 3  sean hannity is giddy and offended that finall...          News   fake
# 4  21st century wire says back in august 2013 uni...   Middle-east   fake

# %%
# Removing stopwords
#import nltk
#nltk.download('stopwords')
#from nltk.corpus import stopwords
#stop = stopwords.words('english')

#data['text'] = data['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

from gensim.parsing.preprocessing import remove_stopwords

def remove_stopwords_from_text(text):
    return remove_stopwords(text)

data['text'] = data['text'].apply(remove_stopwords_from_text)

# %%
data.head()
# Out:
#                                                 text       subject target
# 0  21st century wire says people shot bronxlebano...       US_News   fake
# 1  bipartisan congressional language creates head...      politics   fake
# 2  brussels reuters european union’s chief execut...  politicsNews   true
# 3  sean hannity giddy offended finally like great...          News   fake
# 4  21st century wire says august 2013 united nati...   Middle-east   fake

# %% [markdown]
# ## Basic data exploration

# %%
# How many articles per subject?
print(data.groupby(['subject'])['text'].count())
data.groupby(['subject'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# subject
# Government News     1570
# Middle-east          778
# News                9050
# US_News              783
# left-news           4459
# politics            6841
# politicsNews       11272
# worldnews          10145
# Name: text, dtype: int64

# %%
# How many fake and real articles?
print(data.groupby(['target'])['text'].count())
data.groupby(['target'])['text'].count().plot(kind="bar")
plt.show()
# Out:
# target
# fake    23481
# true    21417
# Name: text, dtype: int64

# %%
# Word cloud for fake news
from wordcloud import WordCloud

fake_data = data[data["target"] == "fake"]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Word cloud for real news
from wordcloud import WordCloud

real_data = data[data["target"] == "true"]
all_words = ' '.join([text for text in fake_data.text])

wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)

plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Most frequent words counter (Code adapted from https://www.kaggle.com/rodolfoluna/fake-news-detector)   
from nltk import tokenize

token_space = tokenize.WhitespaceTokenizer()

def counter(text, column_text, quantity):
    all_words = ' '.join([text for text in text[column_text]])
    token_phrase = token_space.tokenize(all_words)
    frequency = nltk.FreqDist(token_phrase)
    df_frequency = pd.DataFrame({"Word": list(frequency.keys()),
                                   "Frequency": list(frequency.values())})
    df_frequency = df_frequency.nlargest(columns = "Frequency", n = quantity)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequency, x = "Word", y = "Frequency", color = 'blue')
    ax.set(ylabel = "Count")
    plt.xticks(rotation='vertical')
    plt.show()

# %%
# Most frequent words in fake news
counter(data[data["target"] == "fake"], "text", 20)

# %%
# Most frequent words in real news
counter(data[data["target"] == "true"], "text", 20)

# %% [markdown]
# ## Modeling

# %%
# Function to plot the confusion matrix (code from https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html)
from sklearn import metrics
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Peparing the data

# %%
# Split the data
X_train,X_test,y_train,y_test = train_test_split(data['text'], data.target, test_size=0.2, random_state=42)

# %% [markdown]
# # **Naive Bayes**

# %%
dct = dict()

from sklearn.naive_bayes import MultinomialNB

NB_classifier = MultinomialNB()
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', NB_classifier)])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))

dct['Naive Bayes'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 95.14%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # **Logistic regression**

# %%
# Vectorizing and applying TF-IDF
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())])

# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Logistic Regression'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 98.93%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# Vectorizing and applying TF-IDF
pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', DecisionTreeClassifier(criterion= 'entropy',
                                           max_depth = 20, 
                                           splitter='best', 
                                           random_state=42))])
# Fitting the model
model = pipe.fit(X_train, y_train)

# Accuracy
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Decision Tree'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.58%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', RandomForestClassifier(n_estimators=50, criterion="entropy"))])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['Random Forest'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.3%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## **SVM**

# %%
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', clf)])

model = pipe.fit(X_train, y_train)
prediction = model.predict(X_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
dct['SVM'] = round(accuracy_score(y_test, prediction)*100,2)
# Out:
# accuracy: 99.44%

# %%
cm = metrics.confusion_matrix(y_test, prediction)
plot_confusion_matrix(cm, classes=['Fake', 'Real'])
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# # **Comparing** **Different Models**

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,7))
plt.bar(list(dct.keys()),list(dct.values()))
plt.ylim(90,100)
plt.yticks((91, 92, 93, 94, 95, 96, 97, 98, 99, 100))
# Out:
# ([<matplotlib.axis.YTick at 0x18101096a00>,
#   <matplotlib.axis.YTick at 0x18101096670>,
#   <matplotlib.axis.YTick at 0x181038b14c0>,
#   <matplotlib.axis.YTick at 0x18104447880>,
#   <matplotlib.axis.YTick at 0x18104447d90>,
#   <matplotlib.axis.YTick at 0x181044302e0>,
#   <matplotlib.axis.YTick at 0x181044307f0>,
#   <matplotlib.axis.YTick at 0x18104430d00>,
#   <matplotlib.axis.YTick at 0x1810446a250>,
#   <matplotlib.axis.YTick at 0x18104430a30>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
print(X_test.iloc[0])
# Out:
# north korea said monday successfully conducted newly developed midtolong range missile test sunday supervised leader kim jong aimed verifying capability carry large scale heavy nuclear warhead kim accused united states browbeating countries nukes warned washington misjudge reality mainland north s sighting range strike north s official kcna news agency reportedthe north fired ballistic missile landed sea near russia sunday launch washington called message south korea days new president took office pledging engage pyongyang dialoguethe missile launched highest angle affect security neighboring countries flew 787 kilometers 490 miles reaching altitude 21115 kilometers 1312 miles kcna saidexperts said altitude reached missile tested sunday meant launched high trajectory limit lateral distance traveled fired standard trajectory range 4000 2500 miles experts said testfire aimed verifying tactical technological specifications newly developed ballistic rocket capable carrying largesize heavy nuclear warhead kcna said north korea believed developing intercontinental ballistic missile icbm capable carrying nuclear warhead reaching mainland united statesthe military s pacific command said type missile fired consistent intercontinental ballistic missile united nations security council meet tuesday discuss north korea s latest missile launch diplomats said sunday requested united states allies south korea japanus ambassador united nations nikki haley called launch message pyongyang south korea election president moon jaein took office wednesdaythe report missile s flight largely consistent south korean japanese assessments sunday flew 700 435 milesand reached altitude 2000 1243 miles higher intermediaterange missile tested february region northwest pyongyang north korea s latest successful missile test represents level performance seen north korean missile washingtonbased monitoring project 38 north said analysis issued sunday appears demonstrated intermediaterange ballistic missile irbm enable reliably strike base guam importantly represent substantial advance developing intercontinental ballistic missile icbm saidfor entire story reuters

# %%
print(X_test.iloc[1])
# Out:
# rhode island city official resigned caught dressing male middle aged bus driver little old lady prove snow shoveling program helping senior citizensapparently unable single real senior citizen press conference director senior services sue stenhouse got man worked nearby senior home wig earrings lipstick dress stand bragged program let s effective disguisealmost immediately reporters began question ridiculous situation sheer audacity stunt initially called stenhouse woman later things began fall apartwhen nbc affiliate wjartv reported bizarre story stenhouse grew angry ve meeting night great public servant city warwick stenhouse said expletive guys reach big lie news days later turning resignation letterthere course lot questions remain unanswered t officials simply ask resident senior home standing join presser need elderly woman shot place thinking stenhouse idea mrs doubtfire chris farley sketchit s difficult fathom stenhouse accounts long promising career rhode island politics ahead torpedo chances monumentally silly colleagues expressed shock alleged deceit asked comment incidentone theory plausible stenhouse s snow removal initiative struggling thanks mild winter fault lack bad weather meant holding press conference brag snow plowing going flames followed series desperate decisions worthy sitcom according witnesses city officials snow shipped senior center dumped background press conference bus driverturnedold woman extension completely fabricated situation whats lie little lipstick allfeatured image mashable

# %%
X_new = X_test.iloc[0]

prediction = model.predict(X_new)
print(prediction)

if(prediction[0]==0):
    print("The new is Real")
else:
    print("The new is Fake")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11696\3789968835.py in <module>
#       1 X_new = X_test.iloc[0]
#       2
# ----> 3 prediction = model.predict(X_new)
#       4 print(prediction)
#       5
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     467         Xt = X
#     468         for _, name, transform in self._iter(with_final=False):
# --> 469             Xt = transform.transform(Xt)
#     470         return self.steps[-1][1].predict(Xt, **predict_params)
#     471
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in transform(self, raw_documents)
#    1371         """
#    1372         if isinstance(raw_documents, str):
# -> 1373             raise ValueError(
#    1374                 "Iterable over raw text documents expected, string object received."
#    1375             )
#
# ValueError: Iterable over raw text documents expected, string object received.
